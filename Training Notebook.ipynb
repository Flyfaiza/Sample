# %% [markdown]
# #this is a heading
# # H1 THIS IS A LEVEL 1 HEADING
# ## H2 THIS IS A LEVEL 2 HEADING
# ### H3 THIS IS A LEVEL 3 HEADING
# #### H4 THIS IS A LEVEL 4 HEADING
# ##### H5 THIS IS A LEVEL 5 HEADING
# ###### H6 THIS IS A LEVEL 6 HEADING

# %% [markdown]
# # Convert the below in marksdown
# **Hi I am in Bold**
#
#
# __Hi I am in Bold__

# %% [markdown]
# # Diplay the text in both bold & Italics
#
# ***Hello world***
#
#
# ___hello world___

# %% [markdown]
# # Execute it as markdown cell
#
# ***THE GLADIATOR***
#
# ![360_F_227888529_Qdxx7956UFM0BftIZLBeLb2a2ASNnRr4.jpg](attachment:05cb9ee6-8615-4bdf-adc2-ec70177a2c77.jpg)

# %% [markdown]
# # Execute a table in Markdown
#
# ***TABULAR DATA***
#
# | Sno | Country |
# |-----|---------|
# | 1 | India |
# | 2 | Australia |
# | 3 | America |
# | 4 | Europe|

# %% [markdown]
# ## Welcome to Python Programming
#
# **This is SN labs New Launcher** : ![image.png](attachment:65f51f4d-a0ca-4412-adc5-a26284636e63.png)

# %% [markdown]
# # Create a Hyperlink
#
# <a href = "https://www.coursera.org/learn/open-source-tools-for-data-science/home"> Tools for Data Science </a>

# %% [markdown]
# # Create a Table
#
# **Data set of Fruits**
#
# | Fruits | Quantity (in KG) | Price (in Rupees) |
# |--------|------------------|-------------------|
# | Mango |           2 | 200 |
# | Banana | 3 | 100 |
# | Grapes | 3 | 120 |
# | Strawberries | 3 | 250 |
# | Apples | 5 | 370 |

# %% [markdown]
# # Create an Ordered List
#
# 1. Python
# 2. Java
# 3. R
# 4. Php
# 5. Ruby

# %% [markdown]
# # Create an Unordered List
#
# * Python
# + Ruby
# - Php
